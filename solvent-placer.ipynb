# %%
import numpy as np
import os
import sys
import pandas as pd
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
from itertools import combinations
import ase
from ase import io
from copy import deepcopy

# %%
# counter = 0
separation = 3.5
FG_numatoms_dict = { # p1 is the vertex from which p2 and p3 are drawn
    'T': {
        'nat': 7,
        'p1': -1,
        'p2': 2,
        'p3': 3
        },
    'TT': {
        'nat': 10,
        'p1': -1,
        'p2': -2,
        'p3': 2
        },
    'DPP': {
        'nat': 18,
        'p1': 6,
        'p2': 5,
        'p3': 1
        },
}
operating_path = r'/Users/connorganley/Library/Mobile Documents/com~apple~CloudDocs/Documents/JHU/2023-2024/polymer-builder/code/input-data/all-polymer-combos/unopt-xyz/'
# Thiophene (T) rings have 6 atoms each 
for xyzfile in os.listdir(operating_path):
    name = xyzfile[:-4].split('-')
    # print(name)
    # add code here to tabulate the polymer xyz file's composition by FG index; e.g. DPP is indices 1-18 (0-17), T is indices 19-25 (18-24), etc.; will be expandable for EDOT etc.
    # if name[0] in ['T', 'TT']:
    #     if name[2] in ['T', 'TT']:
    #         if name[3] in ['T', 'TT']: #, 'EDOT', 'MEET']:
    #             if name[4] in ['T', 'TT']: #, 'EDOT', 'MEET']:
    for solvent_species in ['tpfb']:#'1,2,4-trimethylbenzene', '2-hexanone', '2-propanol', 'acetone', 'acetonitrile', 'acetophenone', 'anisole', 'benzaldehyde', 'carbon disulfide', 'chlorobenzene', 'chloroform', 'cyclohexane', 'cyclohexanone', 'dmf', 'dmso', 'ethanol', 'ethylbenzene', 'hexane', 'mesitylene', 'methanol', 'o-dichlorobenzene', 'o-xylene', 'tetrahydrofuran', 'thiophene', 'toluene', 'water', 'f4tcnq', 'f6tcnnq']:
        
        # Reading in polymer and solvent xyz files
        atom_index_counter = 0
        polymer = ase.io.read(operating_path + xyzfile)
        polymer_solvent = deepcopy(polymer)
        print(f'Polymer Name: {xyzfile[:-4]}')
        solvent = ase.io.read(operating_path + '../../all-solvents/unopt-xyz/' + solvent_species + '.xyz')
        solvent_copy = deepcopy(solvent)
        solvent_center = np.mean(solvent.get_positions(), axis=0)
        solvent_atoms_dist_to_center = solvent.get_positions() - solvent_center
        print(f'Solvent Name: {solvent_species}')

        # ---

        # DPP
        FG_DPP = polymer.get_positions()[atom_index_counter:atom_index_counter+FG_numatoms_dict[name[1]]['nat']]
        atom_index_counter += FG_numatoms_dict[name[1]]['nat']
        DPP_v13 = polymer.get_positions()[FG_numatoms_dict[name[1]]['p3']] - polymer.get_positions()[FG_numatoms_dict[name[1]]['p1']]
        DPP_v12 = polymer.get_positions()[FG_numatoms_dict[name[1]]['p2']] - polymer.get_positions()[FG_numatoms_dict[name[1]]['p1']]
        DPP_normalvec = np.cross(DPP_v13, DPP_v12) # create a normal vector to the FG plane
        DPP_normalvec = np.abs(DPP_normalvec / np.linalg.norm(DPP_normalvec)) # scale normal vector into unit vector
        DPP_center = np.mean([polymer.get_positions()[FG_numatoms_dict[name[1]]['p1']], polymer.get_positions()[FG_numatoms_dict[name[1]]['p2']], polymer.get_positions()[FG_numatoms_dict[name[1]]['p3']]], axis=0)
        
        solvent_position = DPP_center + separation*DPP_normalvec
        placement = solvent_atoms_dist_to_center + solvent_position
        solvent.set_positions(placement)

        for entry in solvent:
            polymer_solvent.append(entry)
        polymer_solvent.write(f'polymer-adspecies-interactions/unopt-xyz/{xyzfile[:-4]}-{solvent_species}.xyz')
        polymer_solvent = deepcopy(polymer)
        solvent = solvent_copy

        print(f'Wrote file {xyzfile[:-4]}-{solvent_species}.xyz')

                        # ---

                        # # Functional Group A1
                        # FG_A1 = polymer.get_positions()[atom_index_counter:atom_index_counter+FG_numatoms_dict[name[0]]['nat']]
                        # atom_index_counter += FG_numatoms_dict[name[0]]['nat']
                        # A1_v13 = FG_A1[FG_numatoms_dict[name[0]]['p3']] - FG_A1[FG_numatoms_dict[name[0]]['p1']]
                        # A1_v12 = FG_A1[FG_numatoms_dict[name[0]]['p2']] - FG_A1[FG_numatoms_dict[name[0]]['p1']]
                        # A1_normalvec = np.cross(A1_v13, A1_v12)
                        # A1_normalvec = np.abs(A1_normalvec / np.linalg.norm(A1_normalvec))
                        # A1_center = np.mean([FG_A1[FG_numatoms_dict[name[0]]['p1']], FG_A1[FG_numatoms_dict[name[0]]['p2']], FG_A1[FG_numatoms_dict[name[0]]['p3']]], axis=0)

                        # solvent_position = A1_center + separation*A1_normalvec
                        # placement = solvent_atoms_dist_to_center + solvent_position
                        # solvent.set_positions(placement)

                        # for entry in solvent:
                        #     polymer_solvent.append(entry)
                        # polymer_solvent.write(f'{xyzfile[:-4]}-{solvent_species}-A1.xyz')
                        # polymer_solvent = deepcopy(polymer)
                        # solvent = solvent_copy

                        # print(f'Wrote file {xyzfile[:-4]}-{solvent_species}-A1.xyz')
                        
                        # # ---

                        # # Functional Group A2
                        # FG_A2 = polymer.get_positions()[atom_index_counter:atom_index_counter+FG_numatoms_dict[name[2]]['nat']]
                        # atom_index_counter += FG_numatoms_dict[name[2]]['nat']
                        # A2_v13 = FG_A2[FG_numatoms_dict[name[2]]['p3']] - FG_A2[FG_numatoms_dict[name[2]]['p1']]
                        # A2_v12 = FG_A2[FG_numatoms_dict[name[2]]['p2']] - FG_A2[FG_numatoms_dict[name[2]]['p1']]
                        # A2_normalvec = np.cross(A2_v13, A2_v12)
                        # A2_normalvec = np.abs(A2_normalvec / np.linalg.norm(A2_normalvec))
                        # A2_center = np.mean([FG_A2[FG_numatoms_dict[name[2]]['p1']], FG_A2[FG_numatoms_dict[name[2]]['p2']], FG_A2[FG_numatoms_dict[name[2]]['p3']]], axis=0)

                        # solvent_position = A2_center + separation*A2_normalvec
                        # placement = solvent_atoms_dist_to_center + solvent_position
                        # solvent.set_positions(placement)

                        # for entry in solvent:
                        #     polymer_solvent.append(entry)
                        # polymer_solvent.write(f'{xyzfile[:-4]}-{solvent_species}-A2.xyz')
                        # polymer_solvent = deepcopy(polymer)
                        # solvent = solvent_copy

                        # print(f'Wrote file {xyzfile[:-4]}-{solvent_species}-A2.xyz')
                        
                        # # ---

                        # # Functional Group B
                        # FG_B = polymer.get_positions()[atom_index_counter:atom_index_counter+FG_numatoms_dict[name[3]]['nat']]
                        # atom_index_counter += FG_numatoms_dict[name[3]]['nat']
                        # B_v13 = FG_B[FG_numatoms_dict[name[3]]['p3']] - FG_B[FG_numatoms_dict[name[3]]['p1']]
                        # B_v12 = FG_B[FG_numatoms_dict[name[3]]['p2']] - FG_B[FG_numatoms_dict[name[3]]['p1']]
                        # B_normalvec = np.cross(B_v13, B_v12)
                        # B_normalvec = np.abs(B_normalvec / np.linalg.norm(B_normalvec))
                        # B_center = np.mean([FG_B[FG_numatoms_dict[name[3]]['p1']], FG_B[FG_numatoms_dict[name[3]]['p2']], FG_B[FG_numatoms_dict[name[3]]['p3']]], axis=0)

                        # solvent_position = B_center + separation*B_normalvec
                        # placement = solvent_atoms_dist_to_center + solvent_position
                        # solvent.set_positions(placement)

                        # for entry in solvent:
                        #     polymer_solvent.append(entry)
                        # polymer_solvent.write(f'{xyzfile[:-4]}-{solvent_species}-B.xyz')
                        # polymer_solvent = deepcopy(polymer)
                        # solvent = solvent_copy

                        # print(f'Wrote file {xyzfile[:-4]}-{solvent_species}-B.xyz')
                        
                        # # ---

                        # # Functional Group C
                        # FG_C = polymer.get_positions()[atom_index_counter:atom_index_counter+FG_numatoms_dict[name[4]]['nat']]
                        # atom_index_counter += FG_numatoms_dict[name[4]]['nat']
                        # C_v13 = FG_C[FG_numatoms_dict[name[4]]['p3']] - FG_C[FG_numatoms_dict[name[4]]['p1']]
                        # C_v12 = FG_C[FG_numatoms_dict[name[4]]['p2']] - FG_C[FG_numatoms_dict[name[4]]['p1']]
                        # C_normalvec = np.cross(C_v13, C_v12)
                        # C_normalvec = np.abs(C_normalvec / np.linalg.norm(C_normalvec))
                        # C_center = np.mean([FG_C[FG_numatoms_dict[name[4]]['p1']], FG_C[FG_numatoms_dict[name[4]]['p2']], FG_C[FG_numatoms_dict[name[4]]['p3']]], axis=0)

                        # solvent_position = C_center + separation*C_normalvec
                        # placement = solvent_atoms_dist_to_center + solvent_position
                        # solvent.set_positions(placement)

                        # for entry in solvent:
                        #     polymer_solvent.append(entry)
                        # polymer_solvent.write(f'{xyzfile[:-4]}-{solvent_species}-C.xyz')
                        # polymer_solvent = deepcopy(polymer)
                        # solvent = solvent_copy

                        # print(f'Wrote file {xyzfile[:-4]}-{solvent_species}-C.xyz')

                    # break
                    # select solvent molecules: water, n-hexane, acetonitrile, mesitylene
                    # identify where to place them above polymer FGs
# Out:
# Polymer Name: T-DPP-T-NDT-TT
# Solvent Name: tpfb
# Wrote file T-DPP-T-NDT-TT-tpfb.xyz
# Polymer Name: TT-DPP-TT-TT-T6C
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-TT-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-EDOT-BZ
# Solvent Name: tpfb
# Wrote file T-DPP-T-EDOT-BZ-tpfb.xyz
# Polymer Name: TT-DPP-TT-EDOT-BZ
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-EDOT-BZ-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-EDOT-T6C
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-EDOT-T6C-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-NDT-T6C
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-NDT-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-EDOT-BZ
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-EDOT-BZ-tpfb.xyz
# Polymer Name: T-DPP-T-T6C-T
# Solvent Name: tpfb
# Wrote file T-DPP-T-T6C-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-MEET-MEET
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-MEET-MEET-tpfb.xyz
# Polymer Name: T-DPP-T-BZ-NDT
# Solvent Name: tpfb
# Wrote file T-DPP-T-BZ-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T-T6C
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T-T6C-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-EDOT-T
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-EDOT-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T-TT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T-TT-tpfb.xyz
# Polymer Name: T-DPP-T-T-T
# Solvent Name: tpfb
# Wrote file T-DPP-T-T-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-TT-SNS
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-TT-SNS-tpfb.xyz
# Polymer Name: TT-DPP-TT-T-MEET
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T-MEET-tpfb.xyz
# Polymer Name: T-DPP-T-SNS-B3TA
# Solvent Name: tpfb
# Wrote file T-DPP-T-SNS-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-B3TA-SNS
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-B3TA-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-BZ-TT
# Solvent Name: tpfb
# Wrote file T-DPP-T-BZ-TT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-EDOT-NDT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-EDOT-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-MEET-B3TA
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-MEET-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-EDOT-EDOT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-EDOT-EDOT-tpfb.xyz
# Polymer Name: T-DPP-T-SNS-TT
# Solvent Name: tpfb
# Wrote file T-DPP-T-SNS-TT-tpfb.xyz
# Polymer Name: TT-DPP-TT-TT-T
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-TT-T-tpfb.xyz
# Polymer Name: TT-DPP-TT-MEET-T6C
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-MEET-T6C-tpfb.xyz
# Polymer Name: TT-DPP-TT-SNS-B3TA
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-SNS-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-BZ-SNS
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-BZ-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-TT-NDT
# Solvent Name: tpfb
# Wrote file T-DPP-T-TT-NDT-tpfb.xyz
# Polymer Name: T-DPP-T-EDOT-TT
# Solvent Name: tpfb
# Wrote file T-DPP-T-EDOT-TT-tpfb.xyz
# Polymer Name: TT-DPP-TT-EDOT-TT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-EDOT-TT-tpfb.xyz
# Polymer Name: T-DPP-T-NDT-BZ
# Solvent Name: tpfb
# Wrote file T-DPP-T-NDT-BZ-tpfb.xyz
# Polymer Name: TT-DPP-TT-B3TA-B3TA
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-B3TA-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-BZ-EDOT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-BZ-EDOT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T-BZ
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T-BZ-tpfb.xyz
# Polymer Name: T-DPP-T-MEET-T6C
# Solvent Name: tpfb
# Wrote file T-DPP-T-MEET-T6C-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-TT-EDOT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-TT-EDOT-tpfb.xyz
# Polymer Name: TT-DPP-TT-BZ-T6C
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-BZ-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-MEET-B3TA
# Solvent Name: tpfb
# Wrote file T-DPP-T-MEET-B3TA-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-EDOT-TT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-EDOT-TT-tpfb.xyz
# Polymer Name: T-DPP-T-SNS-BZ
# Solvent Name: tpfb
# Wrote file T-DPP-T-SNS-BZ-tpfb.xyz
# Polymer Name: T-DPP-T-BZ-BZ
# Solvent Name: tpfb
# Wrote file T-DPP-T-BZ-BZ-tpfb.xyz
# Polymer Name: TT-DPP-TT-B3TA-T
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-B3TA-T-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T6C-MEET
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T6C-MEET-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T-B3TA
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T-B3TA-tpfb.xyz
# Polymer Name: TT-DPP-TT-MEET-EDOT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-MEET-EDOT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T-B3TA
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T-B3TA-tpfb.xyz
# Polymer Name: TT-DPP-TT-NDT-EDOT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-NDT-EDOT-tpfb.xyz
# Polymer Name: T-DPP-T-B3TA-EDOT
# Solvent Name: tpfb
# Wrote file T-DPP-T-B3TA-EDOT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-NDT-MEET
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-NDT-MEET-tpfb.xyz
# Polymer Name: T-DPP-T-T6C-B3TA
# Solvent Name: tpfb
# Wrote file T-DPP-T-T6C-B3TA-tpfb.xyz
# Polymer Name: T-DPP-T-B3TA-NDT
# Solvent Name: tpfb
# Wrote file T-DPP-T-B3TA-NDT-tpfb.xyz
# Polymer Name: T-DPP-T-T-SNS
# Solvent Name: tpfb
# Wrote file T-DPP-T-T-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-T6C-TT
# Solvent Name: tpfb
# Wrote file T-DPP-T-T6C-TT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-TT-MEET
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-TT-MEET-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T-T
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T-T-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-BZ-MEET
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-BZ-MEET-tpfb.xyz
# Polymer Name: T-DPP-T-TT-MEET
# Solvent Name: tpfb
# Wrote file T-DPP-T-TT-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-TT-MEET
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-TT-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-BZ-MEET
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-BZ-MEET-tpfb.xyz
# Polymer Name: T-DPP-T-BZ-MEET
# Solvent Name: tpfb
# Wrote file T-DPP-T-BZ-MEET-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-BZ-SNS
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-BZ-SNS-tpfb.xyz
# Polymer Name: TT-DPP-TT-EDOT-MEET
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-EDOT-MEET-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-MEET-SNS
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-MEET-SNS-tpfb.xyz
# Polymer Name: TT-DPP-TT-T-T6C
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-SNS-MEET
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-SNS-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-SNS-T6C
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-SNS-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-SNS-T6C
# Solvent Name: tpfb
# Wrote file T-DPP-T-SNS-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-TT-T
# Solvent Name: tpfb
# Wrote file T-DPP-T-TT-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T6C-SNS
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T6C-SNS-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-BZ-T
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-BZ-T-tpfb.xyz
# Polymer Name: T-DPP-T-T6C-BZ
# Solvent Name: tpfb
# Wrote file T-DPP-T-T6C-BZ-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-SNS-T6C
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-SNS-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-NDT-EDOT
# Solvent Name: tpfb
# Wrote file T-DPP-T-NDT-EDOT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-EDOT-T
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-EDOT-T-tpfb.xyz
# Polymer Name: T-DPP-T-T6C-NDT
# Solvent Name: tpfb
# Wrote file T-DPP-T-T6C-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-TT-SNS
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-TT-SNS-tpfb.xyz
# Polymer Name: TT-DPP-TT-T6C-NDT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T6C-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-B3TA-NDT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-B3TA-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-T6C-B3TA
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T6C-B3TA-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T6C-NDT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T6C-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-B3TA-EDOT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-B3TA-EDOT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-EDOT-SNS
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-EDOT-SNS-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-NDT-T6C
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-NDT-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-T-B3TA
# Solvent Name: tpfb
# Wrote file T-DPP-T-T-B3TA-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-B3TA-MEET
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-B3TA-MEET-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-B3TA-NDT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-B3TA-NDT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T6C-B3TA
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T6C-B3TA-tpfb.xyz
# Polymer Name: T-DPP-T-NDT-MEET
# Solvent Name: tpfb
# Wrote file T-DPP-T-NDT-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-NDT-T6C
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-NDT-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-NDT-T6C
# Solvent Name: tpfb
# Wrote file T-DPP-T-NDT-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T6C-TT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T6C-TT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-EDOT-BZ
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-EDOT-BZ-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-SNS-BZ
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-SNS-BZ-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-B3TA-T6C
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-B3TA-T6C-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-NDT-BZ
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-NDT-BZ-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-SNS-EDOT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-SNS-EDOT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-B3TA-B3TA
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-B3TA-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-TT-NDT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-TT-NDT-tpfb.xyz
# Polymer Name: T-DPP-T-BZ-SNS
# Solvent Name: tpfb
# Wrote file T-DPP-T-BZ-SNS-tpfb.xyz
# Polymer Name: TT-DPP-TT-TT-EDOT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-TT-EDOT-tpfb.xyz
# Polymer Name: T-DPP-T-SNS-T
# Solvent Name: tpfb
# Wrote file T-DPP-T-SNS-T-tpfb.xyz
# Polymer Name: T-DPP-T-TT-EDOT
# Solvent Name: tpfb
# Wrote file T-DPP-T-TT-EDOT-tpfb.xyz
# Polymer Name: T-DPP-T-BZ-EDOT
# Solvent Name: tpfb
# Wrote file T-DPP-T-BZ-EDOT-tpfb.xyz
# Polymer Name: TT-DPP-TT-BZ-EDOT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-BZ-EDOT-tpfb.xyz
# Polymer Name: TT-DPP-TT-EDOT-EDOT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-EDOT-EDOT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-TT-EDOT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-TT-EDOT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-SNS-TT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-SNS-TT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-EDOT-TT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-EDOT-TT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T6C-BZ
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T6C-BZ-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-BZ-EDOT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-BZ-EDOT-tpfb.xyz
# Polymer Name: T-DPP-T-TT-SNS
# Solvent Name: tpfb
# Wrote file T-DPP-T-TT-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-EDOT-T
# Solvent Name: tpfb
# Wrote file T-DPP-T-EDOT-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-BZ-NDT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-BZ-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-MEET-MEET
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-MEET-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-NDT-MEET
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-NDT-MEET-tpfb.xyz
# Polymer Name: T-DPP-T-B3TA-MEET
# Solvent Name: tpfb
# Wrote file T-DPP-T-B3TA-MEET-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-NDT-TT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-NDT-TT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-NDT-EDOT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-NDT-EDOT-tpfb.xyz
# Polymer Name: T-DPP-T-NDT-T
# Solvent Name: tpfb
# Wrote file T-DPP-T-NDT-T-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T6C-EDOT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T6C-EDOT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-NDT-TT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-NDT-TT-tpfb.xyz
# Polymer Name: T-DPP-T-EDOT-B3TA
# Solvent Name: tpfb
# Wrote file T-DPP-T-EDOT-B3TA-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-BZ-NDT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-BZ-NDT-tpfb.xyz
# Polymer Name: T-DPP-T-EDOT-T6C
# Solvent Name: tpfb
# Wrote file T-DPP-T-EDOT-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-TT-T
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-TT-T-tpfb.xyz
# Polymer Name: TT-DPP-TT-MEET-T
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-MEET-T-tpfb.xyz
# Polymer Name: T-DPP-T-TT-TT
# Solvent Name: tpfb
# Wrote file T-DPP-T-TT-TT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-BZ-MEET
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-BZ-MEET-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-SNS-TT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-SNS-TT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-TT-MEET
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-TT-MEET-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T-T
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T6C-BZ
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T6C-BZ-tpfb.xyz
# Polymer Name: T-DPP-T-T-NDT
# Solvent Name: tpfb
# Wrote file T-DPP-T-T-NDT-tpfb.xyz
# Polymer Name: T-DPP-T-B3TA-SNS
# Solvent Name: tpfb
# Wrote file T-DPP-T-B3TA-SNS-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-SNS-B3TA
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-SNS-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-MEET-T6C
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-MEET-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-NDT-BZ
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-NDT-BZ-tpfb.xyz
# Polymer Name: TT-DPP-TT-T6C-SNS
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T6C-SNS-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-TT-NDT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-TT-NDT-tpfb.xyz
# Polymer Name: T-DPP-T-T6C-SNS
# Solvent Name: tpfb
# Wrote file T-DPP-T-T6C-SNS-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-SNS-T6C
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-SNS-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T6C-SNS
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T6C-SNS-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-EDOT-MEET
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-EDOT-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-B3TA-SNS
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-B3TA-SNS-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-MEET-EDOT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-MEET-EDOT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T6C-TT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T6C-TT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-EDOT-B3TA
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-EDOT-B3TA-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-SNS-BZ
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-SNS-BZ-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T-T6C
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-TT-BZ
# Solvent Name: tpfb
# Wrote file T-DPP-T-TT-BZ-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-MEET-NDT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-MEET-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-T-EDOT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T-EDOT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-NDT-B3TA
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-NDT-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T6C-NDT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T6C-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-EDOT-T6C
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-EDOT-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-BZ-T6C
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-BZ-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-SNS-B3TA
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-SNS-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-B3TA-EDOT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-B3TA-EDOT-tpfb.xyz
# Polymer Name: T-DPP-T-EDOT-NDT
# Solvent Name: tpfb
# Wrote file T-DPP-T-EDOT-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-BZ-TT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-BZ-TT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T6C-T
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T6C-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-TT-BZ
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-TT-BZ-tpfb.xyz
# Polymer Name: T-DPP-T-T-T6C
# Solvent Name: tpfb
# Wrote file T-DPP-T-T-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T-TT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T-TT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-B3TA-T
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-B3TA-T-tpfb.xyz
# Polymer Name: T-DPP-T-T-EDOT
# Solvent Name: tpfb
# Wrote file T-DPP-T-T-EDOT-tpfb.xyz
# Polymer Name: TT-DPP-TT-T6C-MEET
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T6C-MEET-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-B3TA-BZ
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-B3TA-BZ-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T6C-EDOT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T6C-EDOT-tpfb.xyz
# Polymer Name: T-DPP-T-MEET-T
# Solvent Name: tpfb
# Wrote file T-DPP-T-MEET-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-SNS-NDT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-SNS-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T-MEET
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T-MEET-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-NDT-B3TA
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-NDT-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-MEET-NDT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-MEET-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-BZ-BZ
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-BZ-BZ-tpfb.xyz
# Polymer Name: T-DPP-T-T6C-MEET
# Solvent Name: tpfb
# Wrote file T-DPP-T-T6C-MEET-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-TT-T6C
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-TT-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-TT-B3TA
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-TT-B3TA-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-SNS-SNS
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-SNS-SNS-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T-BZ
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T-BZ-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T6C-T6C
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T6C-T6C-tpfb.xyz
# Polymer Name: TT-DPP-TT-EDOT-NDT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-EDOT-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-BZ-B3TA
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-BZ-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-TT-TT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-TT-TT-tpfb.xyz
# Polymer Name: TT-DPP-TT-SNS-SNS
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-SNS-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-SNS-SNS
# Solvent Name: tpfb
# Wrote file T-DPP-T-SNS-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-TT-B3TA
# Solvent Name: tpfb
# Wrote file T-DPP-T-TT-B3TA-tpfb.xyz
# Polymer Name: TT-DPP-TT-TT-B3TA
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-TT-B3TA-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-MEET-T6C
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-MEET-T6C-tpfb.xyz
# Polymer Name: TT-DPP-TT-BZ-B3TA
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-BZ-B3TA-tpfb.xyz
# Polymer Name: TT-DPP-TT-T-SNS
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-BZ-B3TA
# Solvent Name: tpfb
# Wrote file T-DPP-T-BZ-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T-NDT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-EDOT-B3TA
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-EDOT-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-B3TA-TT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-B3TA-TT-tpfb.xyz
# Polymer Name: T-DPP-T-NDT-NDT
# Solvent Name: tpfb
# Wrote file T-DPP-T-NDT-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-SNS-MEET
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-SNS-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-NDT-NDT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-NDT-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-BZ-BZ
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-BZ-BZ-tpfb.xyz
# Polymer Name: TT-DPP-TT-MEET-SNS
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-MEET-SNS-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-MEET-TT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-MEET-TT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-SNS-T
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-SNS-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-SNS-EDOT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-SNS-EDOT-tpfb.xyz
# Polymer Name: TT-DPP-TT-B3TA-MEET
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-B3TA-MEET-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-NDT-NDT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-NDT-NDT-tpfb.xyz
# Polymer Name: T-DPP-T-MEET-MEET
# Solvent Name: tpfb
# Wrote file T-DPP-T-MEET-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-MEET-TT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-MEET-TT-tpfb.xyz
# Polymer Name: T-DPP-T-MEET-TT
# Solvent Name: tpfb
# Wrote file T-DPP-T-MEET-TT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-B3TA-T6C
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-B3TA-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-EDOT-EDOT
# Solvent Name: tpfb
# Wrote file T-DPP-T-EDOT-EDOT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-TT-T6C
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-TT-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T-SNS
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T-SNS-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-NDT-SNS
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-NDT-SNS-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-NDT-T
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-NDT-T-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-B3TA-NDT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-B3TA-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T6C-B3TA
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T6C-B3TA-tpfb.xyz
# Polymer Name: TT-DPP-TT-EDOT-T
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-EDOT-T-tpfb.xyz
# Polymer Name: TT-DPP-TT-TT-SNS
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-TT-SNS-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T-MEET
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T-MEET-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-EDOT-SNS
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-EDOT-SNS-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-NDT-EDOT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-NDT-EDOT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-MEET-BZ
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-MEET-BZ-tpfb.xyz
# Polymer Name: TT-DPP-TT-BZ-TT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-BZ-TT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-MEET-B3TA
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-MEET-B3TA-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-EDOT-EDOT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-EDOT-EDOT-tpfb.xyz
# Polymer Name: TT-DPP-TT-MEET-BZ
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-MEET-BZ-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-B3TA-T
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-B3TA-T-tpfb.xyz
# Polymer Name: T-DPP-T-MEET-BZ
# Solvent Name: tpfb
# Wrote file T-DPP-T-MEET-BZ-tpfb.xyz
# Polymer Name: TT-DPP-TT-T-B3TA
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T-B3TA-tpfb.xyz
# Polymer Name: T-DPP-T-MEET-SNS
# Solvent Name: tpfb
# Wrote file T-DPP-T-MEET-SNS-tpfb.xyz
# Polymer Name: TT-DPP-TT-BZ-SNS
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-BZ-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-SNS-MEET
# Solvent Name: tpfb
# Wrote file T-DPP-T-SNS-MEET-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-BZ-T
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-BZ-T-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-MEET-MEET
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-MEET-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-T6C-T
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T6C-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-BZ-T6C
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-BZ-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-B3TA-T6C
# Solvent Name: tpfb
# Wrote file T-DPP-T-B3TA-T6C-tpfb.xyz
# Polymer Name: TT-DPP-TT-TT-BZ
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-TT-BZ-tpfb.xyz
# Polymer Name: TT-DPP-TT-T6C-BZ
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T6C-BZ-tpfb.xyz
# Polymer Name: T-DPP-T-SNS-EDOT
# Solvent Name: tpfb
# Wrote file T-DPP-T-SNS-EDOT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-MEET-EDOT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-MEET-EDOT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-EDOT-B3TA
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-EDOT-B3TA-tpfb.xyz
# Polymer Name: T-DPP-T-EDOT-SNS
# Solvent Name: tpfb
# Wrote file T-DPP-T-EDOT-SNS-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-EDOT-MEET
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-EDOT-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-B3TA-BZ
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-B3TA-BZ-tpfb.xyz
# Polymer Name: T-DPP-T-B3TA-BZ
# Solvent Name: tpfb
# Wrote file T-DPP-T-B3TA-BZ-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-NDT-MEET
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-NDT-MEET-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-B3TA-BZ
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-B3TA-BZ-tpfb.xyz
# Polymer Name: T-DPP-T-T-BZ
# Solvent Name: tpfb
# Wrote file T-DPP-T-T-BZ-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-MEET-T
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-MEET-T-tpfb.xyz
# Polymer Name: TT-DPP-TT-T6C-TT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T6C-TT-tpfb.xyz
# Polymer Name: TT-DPP-TT-BZ-T
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-BZ-T-tpfb.xyz
# Polymer Name: TT-DPP-TT-EDOT-SNS
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-EDOT-SNS-tpfb.xyz
# Polymer Name: TT-DPP-TT-TT-TT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-TT-TT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-SNS-NDT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-SNS-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-NDT-T
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-NDT-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T-EDOT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T-EDOT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T-SNS
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-EDOT-MEET
# Solvent Name: tpfb
# Wrote file T-DPP-T-EDOT-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-T-NDT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T-NDT-tpfb.xyz
# Polymer Name: T-DPP-T-SNS-NDT
# Solvent Name: tpfb
# Wrote file T-DPP-T-SNS-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-SNS-NDT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-SNS-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-B3TA-TT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-B3TA-TT-tpfb.xyz
# Polymer Name: T-DPP-T-B3TA-TT
# Solvent Name: tpfb
# Wrote file T-DPP-T-B3TA-TT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T6C-T6C
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T6C-T6C-tpfb.xyz
# Polymer Name: TT-DPP-TT-B3TA-EDOT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-B3TA-EDOT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-BZ-B3TA
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-BZ-B3TA-tpfb.xyz
# Polymer Name: TT-DPP-TT-B3TA-T6C
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-B3TA-T6C-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-TT-B3TA
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-TT-B3TA-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-SNS-SNS
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-SNS-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-MEET-EDOT
# Solvent Name: tpfb
# Wrote file T-DPP-T-MEET-EDOT-tpfb.xyz
# Polymer Name: TT-DPP-TT-SNS-EDOT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-SNS-EDOT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-B3TA-TT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-B3TA-TT-tpfb.xyz
# Polymer Name: T-DPP-T-T-TT
# Solvent Name: tpfb
# Wrote file T-DPP-T-T-TT-tpfb.xyz
# Polymer Name: TT-DPP-TT-T6C-T6C
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T6C-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-SNS-T
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-SNS-T-tpfb.xyz
# Polymer Name: T-DPP-T-T6C-T6C
# Solvent Name: tpfb
# Wrote file T-DPP-T-T6C-T6C-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-SNS-MEET
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-SNS-MEET-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-MEET-SNS
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-MEET-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-BZ-T6C
# Solvent Name: tpfb
# Wrote file T-DPP-T-BZ-T6C-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T-NDT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T-NDT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-MEET-TT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-MEET-TT-tpfb.xyz
# Polymer Name: TT-DPP-TT-T-TT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T-TT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-TT-TT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-TT-TT-tpfb.xyz
# Polymer Name: TT-DPP-TT-NDT-BZ
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-NDT-BZ-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-EDOT-NDT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-EDOT-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-TT-NDT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-TT-NDT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-B3TA-SNS
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-B3TA-SNS-tpfb.xyz
# Polymer Name: TT-DPP-TT-NDT-T
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-NDT-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-NDT-NDT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-NDT-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-SNS-T
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-SNS-T-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-TT-T
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-TT-T-tpfb.xyz
# Polymer Name: T-DPP-T-T6C-EDOT
# Solvent Name: tpfb
# Wrote file T-DPP-T-T6C-EDOT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-BZ-BZ
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-BZ-BZ-tpfb.xyz
# Polymer Name: TT-DPP-TT-MEET-NDT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-MEET-NDT-tpfb.xyz
# Polymer Name: TT-DPP-TT-NDT-SNS
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-NDT-SNS-tpfb.xyz
# Polymer Name: T-DPP-T-B3TA-T
# Solvent Name: tpfb
# Wrote file T-DPP-T-B3TA-T-tpfb.xyz
# Polymer Name: T-DPP-T-NDT-SNS
# Solvent Name: tpfb
# Wrote file T-DPP-T-NDT-SNS-tpfb.xyz
# Polymer Name: TT-DPP-TT-MEET-B3TA
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-MEET-B3TA-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-T-EDOT
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-T-EDOT-tpfb.xyz
# Polymer Name: TT-DPP-TT-NDT-B3TA
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-NDT-B3TA-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-NDT-SNS
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-NDT-SNS-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-EDOT-T6C
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-EDOT-T6C-tpfb.xyz
# Polymer Name: T-DPP-T-B3TA-B3TA
# Solvent Name: tpfb
# Wrote file T-DPP-T-B3TA-B3TA-tpfb.xyz
# Polymer Name: T-DPP-T-BZ-T
# Solvent Name: tpfb
# Wrote file T-DPP-T-BZ-T-tpfb.xyz
# Polymer Name: TT-DPP-TT-SNS-BZ
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-SNS-BZ-tpfb.xyz
# Polymer Name: TT-DPP-TT-T6C-EDOT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T6C-EDOT-tpfb.xyz
# Polymer Name: T-DPP-T-T-MEET
# Solvent Name: tpfb
# Wrote file T-DPP-T-T-MEET-tpfb.xyz
# Polymer Name: TT-DPP-TT-T-BZ
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T-BZ-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-MEET-T
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-MEET-T-tpfb.xyz
# Polymer Name: TT-DPP-TT-BZ-NDT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-BZ-NDT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T6C-MEET
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T6C-MEET-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-B3TA-B3TA
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-B3TA-B3TA-tpfb.xyz
# Polymer Name: T-DPP-T-MEET-NDT
# Solvent Name: tpfb
# Wrote file T-DPP-T-MEET-NDT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-MEET-BZ
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-MEET-BZ-tpfb.xyz
# Polymer Name: T-DPP-T-NDT-B3TA
# Solvent Name: tpfb
# Wrote file T-DPP-T-NDT-B3TA-tpfb.xyz
# Polymer Name: T-DPP-T-TT-T6C
# Solvent Name: tpfb
# Wrote file T-DPP-T-TT-T6C-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-T6C-T
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-T6C-T-tpfb.xyz
# Polymer Name: TT-DPP-TT-NDT-TT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-NDT-TT-tpfb.xyz
# Polymer Name: EDOT-DPP-EDOT-TT-BZ
# Solvent Name: tpfb
# Wrote file EDOT-DPP-EDOT-TT-BZ-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-BZ-TT
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-BZ-TT-tpfb.xyz
# Polymer Name: TT-DPP-TT-T-T
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-T-T-tpfb.xyz
# Polymer Name: TT-DPP-TT-SNS-TT
# Solvent Name: tpfb
# Wrote file TT-DPP-TT-SNS-TT-tpfb.xyz
# Polymer Name: BZ-DPP-BZ-B3TA-MEET
# Solvent Name: tpfb
# Wrote file BZ-DPP-BZ-B3TA-MEET-tpfb.xyz

# %% [markdown]
# ## Solvent Pairwise Distances

# %%
pairwise_distances = pdist(scaled)
distance_matrix = squareform(pairwise_distances)

pairs = list(combinations(range(len(solvent_data)), 2))

pairwise_distances_with_indices = list(zip(pairs, pairwise_distances))

with open('solvent-pairwise-distances-labeled.txt', 'w') as f:
    for (i, j), distance in pairwise_distances_with_indices:
        f.write(f'{i} {j} {distance}\n')
f.close()
plt.hist(pairwise_distances)
plt.xlabel('Euclidean Pairwise Distance')
plt.ylabel('Frequency')
plt.title('Pairwise distances between Solvents (7 features)')
# print(distance_matrix)
