# %%
import numpy as np
import ase
from ase import io
import re
import scipy.spatial.distance
from copy import deepcopy
import ast
import scipy.optimize

# %%
class Polymer_Build:
    def __init__(self, path_to_structure):
        
        self.name = str(path_to_structure)
        
        print('Polymer_Build class initialized. Reading and creating ase.Atoms object from {0}'.format(self.name))
        self.path_to_structure = path_to_structure
    
        self.Atoms = ase.io.read(self.path_to_structure)
        with open(self.path_to_structure) as f:
            comments = re.search('%%%(.*)%%%', f.readlines()[1]).group(1)
        f.close()
        
        self.attachment_pts_dict = ast.literal_eval(comments) # this is unsafe/unsecure blah blah blah
        print('Attachment points on this molecule are: {0}\n\n'.format(str(self.attachment_pts_dict)))
        
        self.LHS_Reflection_Needed = None
        self.RHS_Reflection_Needed = None

        
    def add_FG(self, FG_Polymer_Build_Object, location=['LHS', 'RHS']):
        # there is a distinction between "global" coordinates, which refer to a position in the Polymer_Build Ensemble (i.e. after >=1 FG has been added) and "local" coordinates, which are positions in the xyz file of the isolated FG being added
        if location == 'LHS':
            
            print('Adding {0} to the {1} of structure {2}'.format(FG_Polymer_Build_Object.name, location, self.name))
            
            added_obj = deepcopy(FG_Polymer_Build_Object)
            
            for key, value in self.attachment_pts_dict.items():
                # find the LHS attachment pt on the target molecule (self)
                if 'L' in key:

                    if value is None:
                        print('LHS has already been terminated. Exiting add_FG() module.')
                        break

                    # calculate the Euclidean distances between the LHS attachment site (on target molecule) and every other atom
                    backbone_LHS_distances_tmp = [] # will take the form [Euclidean distance, chemical symbol, global coordinates (relative to target molecule)]
                    for index, value in enumerate(self.Atoms.get_positions()):
                        backbone_LHS_distances_tmp.append(
                            [np.linalg.norm(value-self.Atoms.get_positions()[self.attachment_pts_dict['L']['index']]),
                             self.Atoms.get_chemical_symbols()[index],
                             value]
                        )
                    
                    # filter SORTED list
                    backbone_LHS_distances_tmp = sorted(backbone_LHS_distances_tmp,key=lambda x: (x[0]))
                    hidden = backbone_LHS_distances_tmp.pop(0) # first element will always be 0 because when i=j
                
                    if backbone_LHS_distances_tmp[0][1] == 'C' and backbone_LHS_distances_tmp[1][1] == 'C':
                        # case where closest 2 atoms to backbone LHS are both C
                        print('Nearest atoms to backbone LHS are both C.')
                        LHS_nearest_atom = backbone_LHS_distances_tmp[0]
                        print('The nearest atom to backbone LHS is {0}'.format(LHS_nearest_atom))
                        self.LHS_Reflection_Needed = False
                    else:
                        print('Nearest atoms to backbone LHS are NOT both C. Filtering NNs list')
                        backbone_LHS_distances_tmp = filter(lambda c: c[1]!='C', sorted(backbone_LHS_distances_tmp,key=lambda x: (x[0])))
                        backbone_LHS_distances_tmp = list(filter(lambda c: c[1]!='H', backbone_LHS_distances_tmp))
                        print('Nearest non-C atom to backbone LHS is: {0}'.format(backbone_LHS_distances_tmp[0]))
                        LHS_nearest_atom = backbone_LHS_distances_tmp[0]
                        self.LHS_Reflection_Needed = True
                    

                    
                    # drawing a vector from LHS_nearest_atom to LHS attachment pt, scaling slightly, then adding to coords of LHS attachment pt
                    translation_vector = self.Atoms.get_positions()[self.attachment_pts_dict['L']['index']] - np.array([1.45, 0, 0])#((self.Atoms.get_positions()[self.attachment_pts_dict['L']['index']] - LHS_nearest_atom[2]) * C_scaling) + self.Atoms.get_positions()[self.attachment_pts_dict['L']['index']]

                    
                    print('Placing a C atom at {0} in global coordinates'.format(translation_vector))
                    
                    # have vector between nearest non C and terminal C, need to put C on the end of it
                    self.Atoms.append(ase.Atom('C', translation_vector))
                    self.attachment_pts_dict['L'] = {'index': -1, 'type': 'FG'}
                    
                    # set positions of added object
                    print('Target structure attachment points: {0}'.format(self.attachment_pts_dict))
                    
                    # calculate the Euclidean distances between the FG RHS attachment site and every other atom
                    FG_RHS_distances_tmp = [] # format: [Euclidean distance, chemical symbol, index, local coordinates]
                    for index, value in enumerate(FG_Polymer_Build_Object.Atoms.get_positions()):
                        FG_RHS_distances_tmp.append(
                            [np.linalg.norm(value-FG_Polymer_Build_Object.Atoms.get_positions()[FG_Polymer_Build_Object.attachment_pts_dict['R']['index']]),
                             FG_Polymer_Build_Object.Atoms.get_chemical_symbols()[index],
                             index,
                             value]
                        )
                    
                    # filter sorted list
                    FG_RHS_distances_tmp = sorted(FG_RHS_distances_tmp,key=lambda x: (x[0]))
                    hidden = FG_RHS_distances_tmp.pop(0) # the first distance will be the identity
                    FG_RHS_distances_tmp_before_filter = deepcopy(FG_RHS_distances_tmp)
                    FG_RHS_distances_tmp = filter(lambda c: c[1]!='C', FG_RHS_distances_tmp)
                    FG_RHS_distances_tmp = list(filter(lambda c: c[1]!='H', FG_RHS_distances_tmp))
                
                    if not FG_RHS_distances_tmp:
                        print('The FG you are adding has only C and H.')
                        FG_Polymer_Build_Object.RHS_Reflection_Needed = False
                        RHS_nearest_atom = FG_RHS_distances_tmp_before_filter[0]
                        print('The nearest atom is {0}'.format(RHS_nearest_atom))
                    elif FG_RHS_distances_tmp[0][0] < 5:
                        RHS_nearest_atom = list(FG_RHS_distances_tmp[0])
                        print('before addition, the closest non-H-C atom on FG RHS C is')
                        print(RHS_nearest_atom)
                        FG_Polymer_Build_Object.RHS_Reflection_Needed = True
                        
                    ##### at this point, we have identified the nearest atoms to the attachment points on the target molecule and the FG, and defined conditions for if reflection about conjugation axis is necessary

                    # test intial configuration, then test if mirrored FG configuration maximizes C-to-nearest distance

                    # R to L vector of FG
                    FG_R_to_L_vector = FG_Polymer_Build_Object.Atoms.get_positions()[FG_Polymer_Build_Object.attachment_pts_dict['L']['index']] - FG_Polymer_Build_Object.Atoms.get_positions()[FG_Polymer_Build_Object.attachment_pts_dict['R']['index']]

                    print('FG R TO L VECTOR: {0}'.format(FG_R_to_L_vector))

                    # this vector vectorizes all positions relative to the RHS attachment point
                    FG_R_to_all_atoms_vectors = FG_Polymer_Build_Object.Atoms.get_positions() - FG_Polymer_Build_Object.Atoms.get_positions()[FG_Polymer_Build_Object.attachment_pts_dict['R']['index']]

                    # rotation matrix created from here: https://en.wikipedia.org/wiki/Rotation_matrix#Rotation_matrix_from_axis_and_angle
                    theta = np.deg2rad(179)
                    
                    (x, y, z) = FG_R_to_L_vector / np.linalg.norm(FG_R_to_L_vector)

                    def generate_rotation_matrix(theta, x, y, z):
                        
                        c = np.cos(theta)
                        s = np.sin(theta)
                        C = 1 - c
                        
                        return np.array([
                            [x*x*C+c, x*y*C-z*s, x*z*C+y*s],
                            [y*x*C+z*s, y*y*C+c, y*z*C-z*s],
                            [z*x*C-y*s, z*y*C+x*s, z*z*C+c]
                        ])

                    C_link_position = self.Atoms.get_positions()[-1]
                    trial_coords_2_rotated_vectors = FG_R_to_all_atoms_vectors.dot(generate_rotation_matrix(theta, x, y, z))
                
                    if self.LHS_Reflection_Needed and FG_Polymer_Build_Object.RHS_Reflection_Needed:
                    
                        print('Both LHS and RHS reflection needed.')
                        
                        # find the distance between nearest atom on FG with RHS @ newly placed C and LHS nearest atom
                        distance_1 = np.linalg.norm((self.Atoms.get_positions()[-1] + FG_R_to_all_atoms_vectors[RHS_nearest_atom[2]]) - (LHS_nearest_atom[2])
                                                   )
                        distance_2 = np.linalg.norm((self.Atoms.get_positions()[-1] + trial_coords_2_rotated_vectors[RHS_nearest_atom[2]]) - (LHS_nearest_atom[2])
                                                   )
                        
                        self.Atoms.pop(-1)
                        
                        if distance_2 > distance_1:
                            # reflected configuration is optimal
                            added_obj.Atoms.set_positions(trial_coords_2_rotated_vectors + C_link_position) #############
                            added_obj.attachment_pts_dict['L']['index'] = added_obj.attachment_pts_dict['L']['index'] + len(self.Atoms.get_positions())
                            self.attachment_pts_dict['L'] = added_obj.attachment_pts_dict['L']

                            for index, value in enumerate(added_obj.Atoms):
                                self.Atoms.append(value)

                            print('Added requested FG to LHS of target molecule in reflected configuration. New attachment points on target are now: {0}\n\n'.format(self.attachment_pts_dict))
                            self.name = FG_Polymer_Build_Object.name + '-' + self.name
                    
                        else:
                            # default configuration is optimal
                            added_obj.Atoms.set_positions(FG_R_to_all_atoms_vectors + C_link_position) ################
                            added_obj.attachment_pts_dict['L']['index'] = added_obj.attachment_pts_dict['L']['index'] + len(self.Atoms.get_positions())
                            self.attachment_pts_dict['L'] = added_obj.attachment_pts_dict['L']

                            for index, value in enumerate(added_obj.Atoms):
                                self.Atoms.append(value)

                            print('Added requested FG to LHS of target molecule. New attachment points on target are now: {0}\n\n'.format(self.attachment_pts_dict))
                            self.name = FG_Polymer_Build_Object.name + '-' + self.name
         
                    else:
                        self.Atoms.pop(-1)
                        added_obj.Atoms.set_positions(FG_R_to_all_atoms_vectors + C_link_position) ###################
                        added_obj.attachment_pts_dict['L']['index'] = added_obj.attachment_pts_dict['L']['index'] + len(self.Atoms.get_positions())
                        self.attachment_pts_dict['L'] = added_obj.attachment_pts_dict['L']

                        for index, value in enumerate(added_obj.Atoms):
                            self.Atoms.append(value)

                        print('Added requested FG to LHS of target molecule. New attachment points on target are now: {0}\n\n'.format(self.attachment_pts_dict))
                        self.name = FG_Polymer_Build_Object.name + '-' + self.name
                        
        if location == 'RHS':
            
            print('Adding {0} to the {1} of structure {2}'.format(FG_Polymer_Build_Object.name, location, self.name))
            
            added_obj = deepcopy(FG_Polymer_Build_Object)
            
            for key, value in self.attachment_pts_dict.items():
                # find the LHS attachment pt on the target molecule (self)
                if 'R' in key:
                    
                    if value is None:
                        print('RHS has already been terminated. Exiting add_FG() module.')
                        break

                    # calculate the Euclidean distances between the LHS attachment site (on target molecule) and every other atom
                    backbone_RHS_distances_tmp = [] # will take the form [Euclidean distance, chemical symbol, global coordinates (relative to target molecule)]
                    for index, value in enumerate(self.Atoms.get_positions()):
                        backbone_RHS_distances_tmp.append(
                            [np.linalg.norm(value-self.Atoms.get_positions()[self.attachment_pts_dict['R']['index']]),
                             self.Atoms.get_chemical_symbols()[index],
                             value]
                        )
                    
                    # filter SORTED list
                    backbone_RHS_distances_tmp = sorted(backbone_RHS_distances_tmp,key=lambda x: (x[0]))
                    hidden = backbone_RHS_distances_tmp.pop(0) # first element will always be 0 because when i=j
                
                    if backbone_RHS_distances_tmp[0][1] == 'C' and backbone_RHS_distances_tmp[1][1] == 'C':
                        # case where closest 2 atoms to backbone RHS are both C
                        print('Nearest atoms to backbone RHS are both C.')
                        RHS_nearest_atom = backbone_RHS_distances_tmp[0]
                        print('The nearest atom to backbone RHS is {0}'.format(RHS_nearest_atom))
                        self.RHS_Reflection_Needed = False
                    else:
                        print('Nearest atoms to backbone RHS are NOT both C. Filtering NNs list')
                        backbone_RHS_distances_tmp = filter(lambda c: c[1]!='C', sorted(backbone_RHS_distances_tmp,key=lambda x: (x[0])))
                        backbone_RHS_distances_tmp = list(filter(lambda c: c[1]!='H', backbone_RHS_distances_tmp))
                        print('Nearest non-C atom to backbone RHS is: {0}'.format(backbone_RHS_distances_tmp[0]))
                        RHS_nearest_atom = backbone_RHS_distances_tmp[0]
                        self.RHS_Reflection_Needed = True
                    

                    
                    # drawing a vector from RHS_nearest_atom to RHS attachment pt, scaling slightly, then adding to coords of RHS attachment pt
                    translation_vector = self.Atoms.get_positions()[self.attachment_pts_dict['R']['index']] + np.array([1.45, 0, 0])

                    
                    print('Placing a C atom at {0} in global coordinates'.format(translation_vector))
                    
                    # have vector between nearest non C and terminal C, need to put C on the end of it
                    self.Atoms.append(ase.Atom('C', translation_vector))
                    self.attachment_pts_dict['R'] = {'index': -1, 'type': 'FG'}
                    
                    # set positions of added object
                    print('Target structure attachment points: {0}'.format(self.attachment_pts_dict))
                    
                    # calculate the Euclidean distances between the FG RHS attachment site and every other atom
                    FG_LHS_distances_tmp = [] # format: [Euclidean distance, chemical symbol, index, local coordinates]
                    for index, value in enumerate(FG_Polymer_Build_Object.Atoms.get_positions()):
                        FG_LHS_distances_tmp.append(
                            [np.linalg.norm(value-FG_Polymer_Build_Object.Atoms.get_positions()[FG_Polymer_Build_Object.attachment_pts_dict['L']['index']]),
                             FG_Polymer_Build_Object.Atoms.get_chemical_symbols()[index],
                             index,
                             value]
                        )
                    
                    # filter sorted list
                    FG_LHS_distances_tmp = sorted(FG_LHS_distances_tmp,key=lambda x: (x[0]))
                    hidden = FG_LHS_distances_tmp.pop(0) # the first distance will be the identity
                    FG_LHS_distances_tmp_before_filter = deepcopy(FG_LHS_distances_tmp)
                    FG_LHS_distances_tmp = filter(lambda c: c[1]!='C', FG_LHS_distances_tmp)
                    FG_LHS_distances_tmp = list(filter(lambda c: c[1]!='H', FG_LHS_distances_tmp))
                
                    if not FG_LHS_distances_tmp:
                        print('The FG you are adding has only C and H.')
                        FG_Polymer_Build_Object.LHS_Reflection_Needed = False
                        LHS_nearest_atom = FG_LHS_distances_tmp_before_filter[0]
                        print('The nearest atom is {0}'.format(LHS_nearest_atom))
                    elif FG_LHS_distances_tmp[0][0] < 5:
                        LHS_nearest_atom = list(FG_LHS_distances_tmp[0])
                        print('before addition, the closest non-H-C atom on FG RHS C is')
                        print(LHS_nearest_atom)
                        FG_Polymer_Build_Object.LHS_Reflection_Needed = True
                        
                    ##### at this point, we have identified the nearest atoms to the attachment points on the target molecule and the FG, and defined conditions for if reflection about conjugation axis is necessary

                    # test intial configuration, then test if 180-deg rotated FG configuration maximizes C-to-nearest distance

                    # L to R vector of FG
                    FG_L_to_R_vector = FG_Polymer_Build_Object.Atoms.get_positions()[FG_Polymer_Build_Object.attachment_pts_dict['R']['index']] - FG_Polymer_Build_Object.Atoms.get_positions()[FG_Polymer_Build_Object.attachment_pts_dict['L']['index']]

                    print('FG L TO R VECTOR: {0}'.format(FG_L_to_R_vector))

                    # this vector vectorizes all positions relative to the RHS attachment point
                    FG_L_to_all_atoms_vectors = FG_Polymer_Build_Object.Atoms.get_positions() - FG_Polymer_Build_Object.Atoms.get_positions()[FG_Polymer_Build_Object.attachment_pts_dict['L']['index']]

                    # rotation matrix created from here: https://en.wikipedia.org/wiki/Rotation_matrix#Rotation_matrix_from_axis_and_angle
                    theta = np.deg2rad(179)
                    
                    (x, y, z) = FG_L_to_R_vector / np.linalg.norm(FG_L_to_R_vector)

                    def generate_rotation_matrix(theta, x, y, z):
                        
                        c = np.cos(theta)
                        s = np.sin(theta)
                        C = 1 - c
                        
                        return np.array([
                            [x*x*C+c, x*y*C-z*s, x*z*C+y*s],
                            [y*x*C+z*s, y*y*C+c, y*z*C-z*s],
                            [z*x*C-y*s, z*y*C+x*s, z*z*C+c]
                        ])

                    C_link_position = self.Atoms.get_positions()[-1]
                    trial_coords_2_rotated_vectors = FG_L_to_all_atoms_vectors.dot(generate_rotation_matrix(theta, x, y, z))
                
                    if self.RHS_Reflection_Needed and FG_Polymer_Build_Object.LHS_Reflection_Needed:
                    
                        print('Both RHS and LHS reflection needed.')
                        
                        # find the distance between nearest atom on FG with RHS @ newly placed C and LHS nearest atom
                        distance_1 = np.linalg.norm((self.Atoms.get_positions()[-1] + FG_L_to_all_atoms_vectors[LHS_nearest_atom[2]]) - (RHS_nearest_atom[2])
                                                   )
                        distance_2 = np.linalg.norm((self.Atoms.get_positions()[-1] + trial_coords_2_rotated_vectors[LHS_nearest_atom[2]]) - (RHS_nearest_atom[2])
                                                   )
                        
                        self.Atoms.pop(-1)
                        
                        if distance_2 > distance_1:
                            # reflected configuration is optimal
                            added_obj.Atoms.set_positions(trial_coords_2_rotated_vectors + C_link_position) #############
                            added_obj.attachment_pts_dict['R']['index'] = added_obj.attachment_pts_dict['R']['index'] + len(self.Atoms.get_positions())
                            self.attachment_pts_dict['R'] = added_obj.attachment_pts_dict['R']

                            for index, value in enumerate(added_obj.Atoms):
                                self.Atoms.append(value)

                            print('Added requested FG to RHS of target molecule in reflected configuration. New attachment points on target are now: {0}\n\n'.format(self.attachment_pts_dict))
                            self.name = self.name + '-' + FG_Polymer_Build_Object.name
                    
                        else:
                            # default configuration is optimal
                            added_obj.Atoms.set_positions(FG_L_to_all_atoms_vectors + C_link_position) ################
                            added_obj.attachment_pts_dict['R']['index'] = added_obj.attachment_pts_dict['R']['index'] + len(self.Atoms.get_positions())
                            self.attachment_pts_dict['R'] = added_obj.attachment_pts_dict['R']

                            for index, value in enumerate(added_obj.Atoms):
                                self.Atoms.append(value)

                            print('Added requested FG to RHS of target molecule. New attachment points on target are now: {0}\n\n'.format(self.attachment_pts_dict))
                            self.name = self.name + '-' + FG_Polymer_Build_Object.name
         
                    else:
                        self.Atoms.pop(-1)
                        added_obj.Atoms.set_positions(FG_L_to_all_atoms_vectors + C_link_position) ###################
                        added_obj.attachment_pts_dict['R']['index'] = added_obj.attachment_pts_dict['R']['index'] + len(self.Atoms.get_positions())
                        self.attachment_pts_dict['R'] = added_obj.attachment_pts_dict['R']

                        for index, value in enumerate(added_obj.Atoms):
                            self.Atoms.append(value)

                        print('Added requested FG to RHS of target molecule. New attachment points on target are now: {0}\n\n'.format(self.attachment_pts_dict))
                        self.name = self.name + '-' + FG_Polymer_Build_Object.name

    def terminate(self, location):
        if location == 'LHS':
            
            print('Adding teminal methyl to the {0} of structure {1}'.format(location, self.name))
            
            for key, value in self.attachment_pts_dict.items():
                # find the LHS attachment pt on the target molecule (self)
                if 'L' in key:

                    if value is None:
                        print('LHS has already been terminated. Exiting terminate() module.')
                        break

                    # drawing a vector from LHS_nearest_atom to LHS attachment pt, scaling slightly, then adding to coords of LHS attachment pt
                    translation_vector = self.Atoms.get_positions()[self.attachment_pts_dict['L']['index']] - np.array([1.45, 0, 0])#((self.Atoms.get_positions()[self.attachment_pts_dict['L']['index']] - LHS_nearest_atom[2]) * C_scaling) + self.Atoms.get_positions()[self.attachment_pts_dict['L']['index']]

                    
                    print('Placing a C atom at {0} in global coordinates'.format(translation_vector))
                    
                    # have vector between nearest non C and terminal C, need to put C on the end of it
                    self.Atoms.append(ase.Atom('C', translation_vector))
                    self.Atoms.append(ase.Atom('H', translation_vector + np.array([-0.3, 1, 0.01])))
                    self.Atoms.append(ase.Atom('H', translation_vector + np.array([-0.3, -0.6, 0.8])))
                    self.Atoms.append(ase.Atom('H', translation_vector + np.array([-0.3, -0.4, -0.9])))
                    self.attachment_pts_dict['L'] = None
                    
                    print('LHS has been terminated.')
                    
        if location == 'RHS':
            
            print('Adding teminal methyl to the {0} of structure {1}'.format(location, self.name))
            
            for key, value in self.attachment_pts_dict.items():
                # find the LHS attachment pt on the target molecule (self)
                if 'R' in key:

                    if value is None:
                        print('RHS has already been terminated. Exiting terminate() module.')
                        break

                    # drawing a vector from LHS_nearest_atom to LHS attachment pt, scaling slightly, then adding to coords of LHS attachment pt
                    translation_vector = self.Atoms.get_positions()[self.attachment_pts_dict['R']['index']] + np.array([1.45, 0, 0])#((self.Atoms.get_positions()[self.attachment_pts_dict['L']['index']] - LHS_nearest_atom[2]) * C_scaling) + self.Atoms.get_positions()[self.attachment_pts_dict['L']['index']]

                    
                    print('Placing a C atom at {0} in global coordinates'.format(translation_vector))
                    
                    # have vector between nearest non C and terminal C, need to put C on the end of it
                    self.Atoms.append(ase.Atom('C', translation_vector))
                    self.Atoms.append(ase.Atom('H', translation_vector - np.array([-0.3, 1, 0.01])))
                    self.Atoms.append(ase.Atom('H', translation_vector - np.array([-0.3, -0.6, 0.8])))
                    self.Atoms.append(ase.Atom('H', translation_vector - np.array([-0.3, -0.4, -0.9])))
                    self.attachment_pts_dict['R'] = None
                    
                    print('RHS has been terminated.')

# %%
backbone = Polymer_Build('DPP-template.xyz')
backbone.name = 'DPP'

a1 = Polymer_Build('A/benzene.xyz')
a1.name = 'BZ'
a2 = Polymer_Build('A/EDOT.xyz')
a2.name = 'EDOT'
a3 = Polymer_Build('A/T.xyz')
a3.name = 'T'
a4 = Polymer_Build('A/TT.xyz')
a4.name = 'TT'

a = [a1, a2, a3, a4]

b1 = Polymer_Build('B/B3TA.xyz')
b1.name = 'B3TA'
b2 = Polymer_Build('B/benzene.xyz')
b2.name = 'BZ'
b3 = Polymer_Build('B/EDOT.xyz')
b3.name = 'EDOT'
b4 = Polymer_Build('B/MEET.xyz')
b4.name = 'MEET'
b5 = Polymer_Build('B/NDT.xyz')
b5.name = 'NDT'
b6 = Polymer_Build('B/SNS.xyz')
b6.name = 'SNS'
b7 = Polymer_Build('B/T.xyz')
b7.name = 'T'
b8 = Polymer_Build('B/T6C.xyz')
b8.name = 'T6C'
b9 = Polymer_Build('B/TT.xyz')
b9.name = 'TT'

b = [b1, b2, b3, b4, b5, b6, b7, b8, b9]

c1 = Polymer_Build('C/B3TA.xyz')
c1.name = 'B3TA'
c2 = Polymer_Build('C/benzene.xyz')
c2.name = 'BZ'
c3 = Polymer_Build('C/EDOT.xyz')
c3.name = 'EDOT'
c4 = Polymer_Build('C/MEET.xyz')
c4.name = 'MEET'
c5 = Polymer_Build('C/NDT.xyz')
c5.name = 'NDT'
c6 = Polymer_Build('C/SNS.xyz')
c6.name = 'SNS'
c7 = Polymer_Build('C/T.xyz')
c7.name = 'T'
c8 = Polymer_Build('C/T6C.xyz')
c8.name = 'T6C'
c9 = Polymer_Build('C/TT.xyz')
c9.name = 'TT'

c = [c1, c2, c3, c4, c5, c6, c7, c8, c9]

for a_index, a_value in enumerate(a):
    for b_index, b_value in enumerate(b):
        for c_index, c_value in enumerate(c):
            backbone.add_FG(a_value, 'LHS')
            backbone.add_FG(a_value, 'RHS')
            backbone.add_FG(b_value, 'RHS')
            backbone.add_FG(c_value, 'RHS')
            backbone.terminate('LHS')
            backbone.terminate('RHS')
            backbone.Atoms.write('all-polymer-combos/{0}.xyz'.format(backbone.name))
            backbone = Polymer_Build('DPP-template.xyz')
            backbone.name = 'DPP'
# Out:
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from A/benzene.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from A/EDOT.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from A/T.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from A/TT.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from B/B3TA.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from B/benzene.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from B/EDOT.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from B/MEET.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from B/NDT.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from B/SNS.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from B/T.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from B/T6C.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from B/TT.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from C/B3TA.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from C/benzene.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from C/EDOT.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from C/MEET.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from C/NDT.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from C/SNS.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from C/T.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from C/T6C.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Polymer_Build class initialized. Reading and creating ase.Atoms object from C/TT.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ-B3TA
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3805349937614768, 'C', array([14.72898, -1.17072, -0.83063])]
# Placing a C atom at [16.19458 -0.08725 -1.68604] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 81, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-B3TA-B3TA
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-B3TA-B3TA
# Placing a C atom at [24.93954  0.22916 -3.37208] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP-BZ-B3TA
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3805349937614768, 'C', array([14.72898, -1.17072, -0.83063])]
# Placing a C atom at [16.19458 -0.08725 -1.68604] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 81, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-B3TA-BZ
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-B3TA-BZ
# Placing a C atom at [20.44114 -0.17968 -1.68604] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding EDOT to the RHS of structure BZ-DPP-BZ-B3TA
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3805349937614768, 'C', array([14.72898, -1.17072, -0.83063])]
# Placing a C atom at [16.19458 -0.08725 -1.68604] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.6893367971189168, 'S', 4, array([ 0.11267,  2.22034, -0.00764])]
# FG L TO R VECTOR: [2.49174 0.02812 0.49157]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 81, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-B3TA-EDOT
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-B3TA-EDOT
# Placing a C atom at [20.13632 -0.05913 -1.19447] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding MEET to the RHS of structure BZ-DPP-BZ-B3TA
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3805349937614768, 'C', array([14.72898, -1.17072, -0.83063])]
# Placing a C atom at [16.19458 -0.08725 -1.68604] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.6816774922677655, 'S', 5, array([-2.69237,  2.10257, -0.01909])]
# FG L TO R VECTOR: [ 0.58954 -1.25593 -0.00674]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 81, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-B3TA-MEET
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-B3TA-MEET
# Placing a C atom at [18.23412 -1.34318 -1.69278] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding NDT to the RHS of structure BZ-DPP-BZ-B3TA
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3805349937614768, 'C', array([14.72898, -1.17072, -0.83063])]
# Placing a C atom at [16.19458 -0.08725 -1.68604] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.6895684000655316, 'S', 3, array([0.71806, 1.52322, 0.     ])]
# FG L TO R VECTOR: [ 8.56562 -1.13265  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 81, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-B3TA-NDT
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-B3TA-NDT
# Placing a C atom at [26.2102  -1.2199  -1.68604] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding SNS to the RHS of structure BZ-DPP-BZ-B3TA
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3805349937614768, 'C', array([14.72898, -1.17072, -0.83063])]
# Placing a C atom at [16.19458 -0.08725 -1.68604] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7182498364033096, 'S', 3, array([-1.73983,  1.2212 ,  1.03994])]
# FG L TO R VECTOR: [ 5.63009 -0.91115 -0.13089]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 81, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-B3TA-SNS
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-B3TA-SNS
# Placing a C atom at [23.27467 -0.9984  -1.81693] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding T to the RHS of structure BZ-DPP-BZ-B3TA
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3805349937614768, 'C', array([14.72898, -1.17072, -0.83063])]
# Placing a C atom at [16.19458 -0.08725 -1.68604] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.6814434928655795, 'S', 6, array([0.43297, 1.56167, 0.     ])]
# FG L TO R VECTOR: [2.50099 0.15481 0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 81, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-B3TA-T
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-B3TA-T
# Placing a C atom at [20.14557  0.06756 -1.68604] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding T6C to the RHS of structure BZ-DPP-BZ-B3TA
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3805349937614768, 'C', array([14.72898, -1.17072, -0.83063])]
# Placing a C atom at [16.19458 -0.08725 -1.68604] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.679467546486088, 'S', 5, array([-0.12991,  0.44068, -0.00766])]
# FG L TO R VECTOR: [ 2.50077  0.02564 -0.12993]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 81, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-B3TA-T6C
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-B3TA-T6C
# Placing a C atom at [20.14535 -0.06161 -1.81597] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding TT to the RHS of structure BZ-DPP-BZ-B3TA
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3805349937614768, 'C', array([14.72898, -1.17072, -0.83063])]
# Placing a C atom at [16.19458 -0.08725 -1.68604] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 81, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-B3TA-TT
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-B3TA-TT
# Placing a C atom at [22.14194  0.72393 -1.68604] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding B3TA to the RHS of structure BZ-DPP-BZ-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344619, 'C', array([9.58706, 0.73796, 0.     ])]
# Placing a C atom at [11.69618 -0.49609  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# FG L TO R VECTOR: [ 7.29496  0.31641 -1.68604]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 49, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-BZ-B3TA
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-BZ-B3TA
# Placing a C atom at [20.44114 -0.17968 -1.68604] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP-BZ-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344619, 'C', array([9.58706, 0.73796, 0.     ])]
# Placing a C atom at [11.69618 -0.49609  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 49, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-BZ-BZ
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-BZ-BZ
# Placing a C atom at [15.94274 -0.58852  0.     ] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding EDOT to the RHS of structure BZ-DPP-BZ-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344619, 'C', array([9.58706, 0.73796, 0.     ])]
# Placing a C atom at [11.69618 -0.49609  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.6893367971189168, 'S', 4, array([ 0.11267,  2.22034, -0.00764])]
# FG L TO R VECTOR: [2.49174 0.02812 0.49157]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 49, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-BZ-EDOT
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-BZ-EDOT
# Placing a C atom at [15.63792 -0.46797  0.49157] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344623, 'C', array([5.3405 , 0.83039, 0.     ])]
# Placing a C atom at [ 7.44962 -0.40366  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding MEET to the RHS of structure BZ-DPP-BZ-BZ
# Nearest atoms to backbone RHS are both C.
# The nearest atom to backbone RHS is [1.3990420211344619, 'C', array([9.58706, 0.73796, 0.     ])]
# Placing a C atom at [11.69618 -0.49609  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.6816774922677655, 'S', 5, array([-2.69237,  2.10257, -0.01909])]
# FG L TO R VECTOR: [ 0.58954 -1.25593 -0.00674]
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 49, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure BZ-DPP-BZ-BZ-MEET
# Placing a C atom at [-6.26812  2.37109  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure BZ-DPP-BZ-BZ-MEET
# Placing a C atom at [ 1.373572e+01 -1.752020e+00 -6.740000e-03] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990420211344616, 'C', 4, array([1.36119, 1.28033, 0.     ])]
# FG R TO L VECTOR: [-2.79656  0.09243  0.     ]
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding BZ to the RHS of structure BZ-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# The FG you are adding has only C and H.
# The nearest atom is [1.3990430197817365, 'C', 2, array([-0.03709,  1.32655,  0.     ])]
# FG L TO R VECTOR: [ 2.79656 -0.09243  0.     ]
# ...
# Nearest non-C atom to backbone RHS is: [1.7069510194495916, 'S', array([ 7.07824, -1.08957,  0.     ])]
# Placing a C atom at [9.15042 0.49995 0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding NDT to the RHS of structure TT-DPP-TT-TT
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.706951019449591, 'S', array([13.0256 , -0.27839,  0.     ])]
# Placing a C atom at [15.09778  1.31113  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.6895684000655316, 'S', 3, array([0.71806, 1.52322, 0.     ])]
# FG L TO R VECTOR: [ 8.56562 -1.13265  0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 49, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure TT-DPP-TT-TT-NDT
# Placing a C atom at [-7.96892  1.46748  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure TT-DPP-TT-TT-NDT
# Placing a C atom at [25.1134   0.17848  0.     ] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding TT to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069510194495916, 'S', 9, array([-0.03024, -0.19636,  0.     ])]
# FG R TO L VECTOR: [-4.49736 -0.81118  0.     ]
# Both LHS and RHS reflection needed.
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding TT to the RHS of structure TT-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding TT to the RHS of structure TT-DPP-TT
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.7069510194495916, 'S', array([ 7.07824, -1.08957,  0.     ])]
# Placing a C atom at [9.15042 0.49995 0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding SNS to the RHS of structure TT-DPP-TT-TT
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.706951019449591, 'S', array([13.0256 , -0.27839,  0.     ])]
# Placing a C atom at [15.09778  1.31113  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7182498364033096, 'S', 3, array([-1.73983,  1.2212 ,  1.03994])]
# FG L TO R VECTOR: [ 5.63009 -0.91115 -0.13089]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 49, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure TT-DPP-TT-TT-SNS
# Placing a C atom at [-7.96892  1.46748  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure TT-DPP-TT-TT-SNS
# Placing a C atom at [22.17787  0.39998 -0.13089] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding TT to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069510194495916, 'S', 9, array([-0.03024, -0.19636,  0.     ])]
# FG R TO L VECTOR: [-4.49736 -0.81118  0.     ]
# Both LHS and RHS reflection needed.
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding TT to the RHS of structure TT-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding TT to the RHS of structure TT-DPP-TT
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.7069510194495916, 'S', array([ 7.07824, -1.08957,  0.     ])]
# Placing a C atom at [9.15042 0.49995 0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding T to the RHS of structure TT-DPP-TT-TT
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.706951019449591, 'S', array([13.0256 , -0.27839,  0.     ])]
# Placing a C atom at [15.09778  1.31113  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.6814434928655795, 'S', 6, array([0.43297, 1.56167, 0.     ])]
# FG L TO R VECTOR: [2.50099 0.15481 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 49, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure TT-DPP-TT-TT-T
# Placing a C atom at [-7.96892  1.46748  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure TT-DPP-TT-TT-T
# Placing a C atom at [19.04877  1.46594  0.     ] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding TT to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069510194495916, 'S', 9, array([-0.03024, -0.19636,  0.     ])]
# FG R TO L VECTOR: [-4.49736 -0.81118  0.     ]
# Both LHS and RHS reflection needed.
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding TT to the RHS of structure TT-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding TT to the RHS of structure TT-DPP-TT
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.7069510194495916, 'S', array([ 7.07824, -1.08957,  0.     ])]
# Placing a C atom at [9.15042 0.49995 0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding T6C to the RHS of structure TT-DPP-TT-TT
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.706951019449591, 'S', array([13.0256 , -0.27839,  0.     ])]
# Placing a C atom at [15.09778  1.31113  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.679467546486088, 'S', 5, array([-0.12991,  0.44068, -0.00766])]
# FG L TO R VECTOR: [ 2.50077  0.02564 -0.12993]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 49, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure TT-DPP-TT-TT-T6C
# Placing a C atom at [-7.96892  1.46748  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure TT-DPP-TT-TT-T6C
# Placing a C atom at [19.04855  1.33677 -0.12993] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding TT to the LHS of structure DPP
# Nearest atoms to backbone LHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone LHS is: [1.3662789678905256, 'N', array([ 0.53085,  3.08576, -0.     ])]
# Placing a C atom at [-2.02156  2.27866  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': -1, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069510194495916, 'S', 9, array([-0.03024, -0.19636,  0.     ])]
# FG R TO L VECTOR: [-4.49736 -0.81118  0.     ]
# Both LHS and RHS reflection needed.
# Added requested FG to LHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}
#
#
# Adding TT to the RHS of structure TT-DPP
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.3664014463180285, 'N', array([ 0.65003, -1.11769, -0.     ])]
# Placing a C atom at [ 3.20306 -0.31123  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 29, 'type': 'FG'}}
#
#
# Adding TT to the RHS of structure TT-DPP-TT
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.7069510194495916, 'S', array([ 7.07824, -1.08957,  0.     ])]
# Placing a C atom at [9.15042 0.49995 0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 39, 'type': 'FG'}}
#
#
# Adding TT to the RHS of structure TT-DPP-TT-TT
# Nearest atoms to backbone RHS are NOT both C. Filtering NNs list
# Nearest non-C atom to backbone RHS is: [1.706951019449591, 'S', array([13.0256 , -0.27839,  0.     ])]
# Placing a C atom at [15.09778  1.31113  0.     ] in global coordinates
# Target structure attachment points: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': -1, 'type': 'FG'}}
# before addition, the closest non-H-C atom on FG RHS C is
# [1.7069417074112399, 'S', 8, array([-3.28324,  2.17149,  0.     ])]
# FG L TO R VECTOR: [4.49736 0.81118 0.     ]
# Both RHS and LHS reflection needed.
# Added requested FG to RHS of target molecule. New attachment points on target are now: {'L': {'index': 18, 'type': 'FG'}, 'R': {'index': 49, 'type': 'FG'}}
#
#
# Adding teminal methyl to the LHS of structure TT-DPP-TT-TT-TT
# Placing a C atom at [-7.96892  1.46748  0.     ] in global coordinates
# LHS has been terminated.
# Adding teminal methyl to the RHS of structure TT-DPP-TT-TT-TT
# Placing a C atom at [21.04514  2.12231  0.     ] in global coordinates
# RHS has been terminated.
# Polymer_Build class initialized. Reading and creating ase.Atoms object from DPP-template.xyz
# Attachment points on this molecule are: {'L': {'index': 0, 'type': 'FG'}, 'R': {'index': 1, 'type': 'FG'}}

# %%
def distance(x1, x2):
    return np.linalg.norm(x1-x2)

distance(np.array([0, 0, 0]), np.array([1, 1, 1]))
# Out:
# 1.7320508075688772
